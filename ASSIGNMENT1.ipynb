# %%
#q21a)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('Cars.csv')
df1.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
df1.mean()
# Out:
# HP     117.469136
# MPG     34.422076
# VOL     98.765432
# SP     121.540272
# WT      32.412577
# dtype: float64

# %%
df1.median()
# Out:
# HP     100.000000
# MPG     35.152727
# VOL    101.000000
# SP     118.208698
# WT      32.734518
# dtype: float64

# %%
df1.mode()
# Out:
#       HP        MPG   VOL          SP         WT
# 0   92.0  29.629936  50.0  118.288996  15.712859
# 1    NaN        NaN   NaN         NaN  15.753535
# 2    NaN        NaN   NaN         NaN  15.769625
# 3    NaN        NaN   NaN         NaN  15.823060
# 4    NaN        NaN   NaN         NaN  15.847758
# ..   ...        ...   ...         ...        ...
# 76   NaN        NaN   NaN         NaN  42.778219
# 77   NaN        NaN   NaN         NaN  43.353123
# 78   NaN        NaN   NaN         NaN  43.390988
# 79   NaN        NaN   NaN         NaN  44.013139
# 80   NaN        NaN   NaN         NaN  52.997752
#
# [81 rows x 5 columns]

# %%
sns.distplot(df1['MPG'])
plt.show()  
#kde= True

# %%
sns.boxplot(df1['MPG'])
plt.show()
warnings.filterwarnings('ignore')


#here the left whisker is longer than right whisker, mean < median , the curve we can see is fairly symmetric.
# Out:
# E:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6696/3336034715.py in <module>
#       1 sns.boxplot(df1['MPG'])
# ----> 2 plt.show()
#       3 warnings.filterwarnings('ignore')
#       4
#       5
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import wa

# %%
df = pd.read_csv('wc-at (2).csv')

#Q21b

# %%
df.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
df.mean()
# Out:
# Waist     91.901835
# AT       101.894037
# dtype: float64

# %%
df.median()
# Out:
# Waist    90.80
# AT       96.54
# dtype: float64

# %%
df.mode()
# Out:
#    Waist     AT
# 0   94.5  121.0
# 1  106.0  123.0
# 2  108.5    NaN

# %%
sns.histplot(df['Waist'])
plt.show()

# %%
sns.histplot(df['AT'])
# Out:
# <AxesSubplot:xlabel='AT', ylabel='Count'>

# %%
sns.boxplot(df['AT'])
plt.show()

# mean> median, right whisker is larger than left whisker,therefore the data is positively skewed.

# %%
sns.boxplot(df['Waist'])
plt.show()

## mean> median, both the whisker are of same lenght, median is slightly shifted towards left.hence, the Data is fairly symetric.

# %%
#Q20

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm

# %%
cars=pd.read_csv('Cars.csv')
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
sns.boxplot(cars.MPG)
# Out:
# <AxesSubplot:xlabel='MPG'>

# %%
# P(MPG>38)
1-stats.norm.cdf(38,cars.MPG.mean(),cars.MPG.std())
# Out:
# 0.3475939251582705

# %%
# P(MPG<40)
1-stats.norm.cdf(40,cars.MPG.mean(),cars.MPG.std())
# Out:
# 0.27065012378483844

# %%
# P(20<MPG<50)
1-stats.norm.cdf(0.50,cars.MPG.mean(),cars.MPG.std())
# Out:
# 0.9998983435126426

# %%
#Q9
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
rec = pd.read_csv('Q9_a.csv')

# %%
rec
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
#skewness

rec.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
#kurtosis

rec.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
rec.mean()
# Out:
# Index    25.50
# speed    15.40
# dist     42.98
# dtype: float64

# %%
rec.median()
# Out:
# Index    25.5
# speed    15.0
# dist     36.0
# dtype: float64

# %%
rec.mode()
# Out:
#     Index  speed  dist
# 0       1   20.0  26.0
# 1       2    NaN   NaN
# 2       3    NaN   NaN
# 3       4    NaN   NaN
# 4       5    NaN   NaN
# 5       6    NaN   NaN
# 6       7    NaN   NaN
# 7       8    NaN   NaN
# 8       9    NaN   NaN
# 9      10    NaN   NaN
# 10     11    NaN   NaN
# 11     12    NaN   NaN
# 12     13    NaN   NaN
# 13     14    NaN   NaN
# 14     15    NaN   NaN
# 15     16    NaN   NaN
# 16     17    NaN   NaN
# 17     18    NaN   NaN
# 18     19    NaN   NaN
# 19     20    NaN   NaN
# 20     21    NaN   NaN
# 21     22    NaN   NaN
# 22     23    NaN   NaN
# 23     24    NaN   NaN
# 24     25    NaN   NaN
# 25     26    NaN   NaN
# 26     27    NaN   NaN
# 27     28    NaN   NaN
# 28     29    NaN   NaN
# 29     30    NaN   NaN
# 30     31    NaN   NaN
# 31     32    NaN   NaN
# 32     33    NaN   NaN
# 33     34    NaN   NaN
# 34     35    NaN   NaN
# 35     36    NaN   NaN
# 36     37    NaN   NaN
# 37     38    NaN   NaN
# 38     39    NaN   NaN
# ...

# %%
crr = pd.read_csv('Q9_b.csv')

# %%
crr
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
#skewness

crr.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
#kurtosis

crr.kurt()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
crr.mean()
# Out:
# Unnamed: 0     41.000000
# SP            121.540272
# WT             32.412577
# dtype: float64

# %%
crr.median()
# Out:
# Unnamed: 0     41.000000
# SP            118.208698
# WT             32.734518
# dtype: float64

# %%
crr.mode()
# Out:
#     Unnamed: 0          SP         WT
# 0            1  118.288996  15.712859
# 1            2         NaN  15.753535
# 2            3         NaN  15.769625
# 3            4         NaN  15.823060
# 4            5         NaN  15.847758
# ..         ...         ...        ...
# 76          77         NaN  42.778219
# 77          78         NaN  43.353123
# 78          79         NaN  43.390988
# 79          80         NaN  44.013139
# 80          81         NaN  52.997752
#
# [81 rows x 3 columns]

# %%
#Q24

from scipy import stats
from scipy.stats import norm

# %%
# Assume Null Hypothesis is: Ho = Avg life of Bulb >= 260 days
# Alternate Hypothesis is: Ha = Avg life of Bulb < 260 days

# %%
# find t-scores at x=260; t=(s_mean-P_mean)/(s_SD/sqrt(n))
t=(260-270)/(90/18**0.5)
t
# Out:
# -0.4714045207910317

# %%
# Find P(X>=260) for null hypothesis

# %%
# p_value=1-stats.t.cdf(abs(t_scores),df=n-1)... Using cdf function
p_value=1-stats.t.cdf(abs(-0.4714),df=17)
p_value
# Out:
# 0.32167411684460556

# %%
#  OR p_value=stats.t.sf(abs(t_score),df=n-1)... Using sf function
p_value=stats.t.sf(abs(-0.4714),df=17)
p_value
# Out:
# 0.32167411684460556

# %%
#Q7
df=pd.read_csv('Q7 (1).csv')

# %%
df
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
df.mean()
# Out:
# C:\Users\HARSHITA\AppData\Local\Temp/ipykernel_5840/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\HARSHITA\AppData\Local\Temp/ipykernel_5840/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
df.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %%
df.var()
# Out:
# C:\Users\HARSHITA\AppData\Local\Temp/ipykernel_5840/1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\HARSHITA\AppData\Local\Temp/ipykernel_5840/3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64
